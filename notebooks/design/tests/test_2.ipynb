# %%
# %load_ext autoreload
# %autoreload 2
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ["PMIX_MCA_gds"]="hash"

# Import useful packages
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs
from qiskit_metal.toolbox_metal import math_and_overrides
from qiskit_metal.qlibrary.core import QComponent
from collections import OrderedDict

# To create plots after geting solution data.
import matplotlib.pyplot as plt
import numpy as np

# Packages for the simple design
from SQDMetal.Comps.Xmon import Xmon
from SQDMetal.Comps.Junctions import JunctionDolanPinStretch

# Set up chip design as planar, multiplanar also available
design = designs.DesignPlanar({}, overwrite_enabled=True)

# Set up chip dimensions
design.chips.main.size.size_x = '500um'
design.chips.main.size.size_y = '500um'
design.chips.main.size.size_z = '500um'
design.chips.main.size.center_x = '0mm'
design.chips.main.size.center_y = '0mm'

# Create the x-mon
xmon = Xmon(design, 'x-mon', options=Dict(pos_x=0, pos_y=0,
                                    vBar_width='24um', hBar_width='24um', vBar_gap=f'{16}um', hBar_gap=f'{16}um',
                                    cross_width=f'{60*2+24}um', cross_height=f'{60*2+24}um',
                                    gap_up='24um', gap_left='24um', gap_right='24um', gap_down='24um'))

# Create the Josephson junction
JunctionDolanPinStretch(design, 'junction', options=Dict(pin_inputs=Dict(start_pin=Dict(component=f'x-mon',pin='right')),
                                                         dist_extend='24um',
                                                         layer=2,
                                                         finger_width='0.4um', t_pad_size='0.385um',
                                                         squid_width='5.4um', prong_width='0.9um'));

# Rebuild the GUI
gui = MetalGUI(design)
gui.rebuild()

# %%
from SQDMetal.PALACE.Eigenmode_Simulation import PALACE_Eigenmode_Simulation
from SQDMetal.Utilities.Materials import MaterialInterface

#Eigenmode Simulation Options
user_defined_options = {
                "mesh_refinement":  0,                             #refines mesh in PALACE - essetially divides every mesh element in half
                "dielectric_material": "silicon",                  #choose dielectric material - 'silicon' or 'sapphire'
                "starting_freq": 5e9,                              #starting frequency in Hz
                "number_of_freqs": 1,                              #number of eigenmodes to find
                "solns_to_save": 1,                                #number of electromagnetic field visualizations to save
                "solver_order": 2,                                 #increasing solver order increases accuracy of simulation, but significantly increases sim time
                "solver_tol": 1.0e-8,                              #error residual tolerance foriterative solver
                "solver_maxits": 200,                              #number of solver iterations
                "fillet_resolution":12,                             #Number of vertices per quarter turn on a filleted path
                "palace_dir":"/home/ruiz/repo/spack/opt/spack/linux-zen3/palace-develop-blpbtxe43ne2or3yo7gou6ycmdwdxuzl/bin/palace",#"PATH/TO/PALACE/BINARY",
                "num_cpus": 8
                }

#Create the Palace Eigenmode simulation
eigen_sim = PALACE_Eigenmode_Simulation(name ='x-mon_test',                                         #name of simulation
                                        metal_design = design,                                      #feed in qiskit metal design
                                        sim_parent_directory = "",                                  #choose directory where mesh file, config file and HPC batch file will be saved
                                        mode = 'simPC',                                             #choose simulation mode 'HPC' or 'simPC'
                                        meshing = 'GMSH',                                           #choose meshing 'GMSH' or 'COMSOL'
                                        user_options = user_defined_options,                        #provide options chosen above
                                        create_files = True)                                        #create mesh, config and HPC batch files

#Add in metals from layer 1 of the design file
eigen_sim.add_metallic(1)

#Add in ground plane for simulation
eigen_sim.add_ground_plane()

#Add in the Josephson junction as a lumped port
eigen_sim.create_port_JosephsonJunction('junction', L_J=4.3e-9, C_J=10e-15)

#Fine-mesh x-mon
eigen_sim.fine_mesh_components(['x-mon'], min_size=8e-6, max_size=100e-6, taper_dist_min=10e-6, metals_only=False)

#Sets up the lossy interfaces for MA, SA and MS interfaces
eigen_sim.setup_EPR_interfaces(metal_air=MaterialInterface('Aluminium-Vacuum'), substrate_air=MaterialInterface('Silicon-Vacuum'), substrate_metal=MaterialInterface('Silicon-Aluminium'))

#Prepares the mesh file and config file
eigen_sim.prepare_simulation()

# %%
eigen_sim.open_mesh_gmsh()

# %%
#run the simulation
eigen_sim.run()
# Out:
# >> /usr/bin/mpirun -n 8 /home/ruiz/repo/spack/opt/spack/linux-zen3/palace-develop-blpbtxe43ne2or3yo7gou6ycmdwdxuzl/bin/palace-x86_64.bin x-mon_test.json
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
#
# --> Warning!
# Output folder is not empty; program will overwrite content! (outputFiles)
# Git changeset ID: 3b8c020
# Running with 8 MPI processes
# Device configuration: cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
# Added 8 elements in 1 iterations of local bisection for under-resolved interior boundaries
# Added 531 duplicate vertices for interior boundaries in the mesh
# Added 1264 duplicate boundary elements for interior boundaries in the mesh
# Added 292 boundary elements for material interfaces to the mesh
#
# Characteristic length and time scales:
#  Lc = 1.000e-03 m, tc = 3.336e-03 ns
# Finished partitioning mesh into 8 subdomains
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-3.000e-04, -3.000e-04, -5.000e-04) m
#  (Xmax, Ymax, Zmax) = (+3.000e-04, +3.000e-04, +5.000e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices           293         388         469        3104
#  edges             2083        2340        2565       18725
#  faces             3562        3698        3833       29586
#  elements          1708        1745        1775       13963
#  neighbors            4           6           7
#
#             minimum     maximum
#  h       0.00561779    0.175171
#  kappa            1     7.07008
#
# Estimated current per-rank memory usage is: Min. 37.2M, Max. 50.1M, Avg. 38.9M, Total 311.2M
# Estimated current per-node memory usage is: Min. 312.0M, Max. 312.0M, Avg. 312.0M, Total 312.0M
#
# Configuring Robin impedance BC for lumped ports at attributes:
#  1: Ls = 9.675e-10 H/sq, Cs = 4.444e-14 F/sq, n = (+0.0,+0.0,+1.0)
#
# Configuring lumped port circuit properties:
#  Index = 1: L = 4.300e-09 H, C = 1.000e-14 F
#
# Configuring Dirichlet PEC BC at attributes:
#  2-3, 6-11
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 2): 21829, ND (p = 2): 96622, RT (p = 2): 130647
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 20, Q = 11 (quadrature order = 4)
#
# Configuring SLEPc eigenvalue solver:
#  Scaling γ = 1.320e+03, δ = 2.209e-04
#  Configuring divergence-free projection
#  Using random starting vector
#  Shift-and-invert σ = 5.000e+00 GHz (1.048e-01)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 18725 unknowns
#  Level 1 (p = 2): 96622 unknowns
#  Level 0 (auxiliary) (p = 1): 3104 unknowns
#  Level 1 (auxiliary) (p = 2): 21829 unknowns
#
# #PETSc Option Table entries:
# -eps_monitor # (source: code)
# #End of PETSc Option Table entries
#
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 1.477775e-02
#   1 (restart 0) KSP residual norm 1.595600e-03
#   2 (restart 0) KSP residual norm 2.697057e-04
#   3 (restart 0) KSP residual norm 4.900270e-05
#   4 (restart 0) KSP residual norm 1.029063e-05
#   5 (restart 0) KSP residual norm 2.295839e-06
#   6 (restart 0) KSP residual norm 5.151319e-07
#   7 (restart 0) KSP residual norm 1.110681e-07
#   8 (restart 0) KSP residual norm 2.562697e-08
#   9 (restart 0) KSP residual norm 5.904041e-09
#  10 (restart 0) KSP residual norm 1.450128e-09
#  11 (restart 0) KSP residual norm 3.468385e-10
#  12 (restart 0) KSP residual norm 7.287881e-11
# FGMRES solver converged in 12 iterations (avg. reduction factor: 2.031e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 1.087048e-02
#   1 (restart 0) KSP residual norm 1.934077e-03
#   2 (restart 0) KSP residual norm 4.305722e-04
#   3 (restart 0) KSP residual norm 8.469763e-05
#   4 (restart 0) KSP residual norm 1.750154e-05
#   5 (restart 0) KSP residual norm 3.947337e-06
#   6 (restart 0) KSP residual norm 8.834271e-07
#   7 (restart 0) KSP residual norm 1.934796e-07
#   8 (restart 0) KSP residual norm 4.042361e-08
#   9 (restart 0) KSP residual norm 8.359868e-09
#  10 (restart 0) KSP residual norm 1.751278e-09
#  11 (restart 0) KSP residual norm 4.085308e-10
#  12 (restart 0) KSP residual norm 9.708101e-11
# FGMRES solver converged in 12 iterations (avg. reduction factor: 2.134e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 6.213200e-02
#   1 (restart 0) KSP residual norm 1.855644e-02
#   2 (restart 0) KSP residual norm 3.079456e-03
#   3 (restart 0) KSP residual norm 5.730123e-04
#   4 (restart 0) KSP residual norm 1.240024e-04
#   5 (restart 0) KSP residual norm 2.841539e-05
#   6 (restart 0) KSP residual norm 6.084266e-06
#   7 (restart 0) KSP residual norm 1.223104e-06
#   8 (restart 0) KSP residual norm 2.497933e-07
#   9 (restart 0) KSP residual norm 4.973128e-08
#  10 (restart 0) KSP residual norm 1.114867e-08
#  11 (restart 0) KSP residual norm 2.612439e-09
#  12 (restart 0) KSP residual norm 6.283128e-10
#  13 (restart 0) KSP residual norm 1.498826e-10
# FGMRES solver converged in 13 iterations (avg. reduction factor: 2.173e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 3.675372e-01
#   1 (restart 0) KSP residual norm 3.158581e-02
#   2 (restart 0) KSP residual norm 4.292787e-03
#   3 (restart 0) KSP residual norm 8.286758e-04
#   4 (restart 0) KSP residual norm 1.897909e-04
#   5 (restart 0) KSP residual norm 4.011441e-05
#   6 (restart 0) KSP residual norm 7.508022e-06
#   7 (restart 0) KSP residual norm 1.514719e-06
#   8 (restart 0) KSP residual norm 3.246293e-07
#   9 (restart 0) KSP residual norm 7.472019e-08
#  10 (restart 0) KSP residual norm 1.588575e-08
#  11 (restart 0) KSP residual norm 2.910594e-09
# FGMRES solver converged in 11 iterations (avg. reduction factor: 1.834e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 4.571756e-02
#   1 (restart 0) KSP residual norm 6.055750e-03
#   2 (restart 0) KSP residual norm 1.089059e-03
#   3 (restart 0) KSP residual norm 1.817722e-04
#   4 (restart 0) KSP residual norm 3.732772e-05
#   5 (restart 0) KSP residual norm 8.350062e-06
#   6 (restart 0) KSP residual norm 1.907381e-06
#   7 (restart 0) KSP residual norm 4.113127e-07
#   8 (restart 0) KSP residual norm 8.728050e-08
#   9 (restart 0) KSP residual norm 1.802647e-08
#  10 (restart 0) KSP residual norm 3.785246e-09
#  11 (restart 0) KSP residual norm 8.493311e-10
#  12 (restart 0) KSP residual norm 1.994770e-10
# FGMRES solver converged in 12 iterations (avg. reduction factor: 2.011e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 2.968733e-01
#   1 (restart 0) KSP residual norm 2.473561e-02
#   2 (restart 0) KSP residual norm 3.235216e-03
#   3 (restart 0) KSP residual norm 5.514445e-04
#   4 (restart 0) KSP residual norm 1.213339e-04
#   5 (restart 0) KSP residual norm 2.686693e-05
#   6 (restart 0) KSP residual norm 5.117832e-06
#   7 (restart 0) KSP residual norm 9.539886e-07
#   8 (restart 0) KSP residual norm 1.886125e-07
#   9 (restart 0) KSP residual norm 4.057568e-08
#  10 (restart 0) KSP residual norm 9.273775e-09
#  11 (restart 0) KSP residual norm 1.890966e-09
# FGMRES solver converged in 11 iterations (avg. reduction factor: 1.799e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 5.625560e-02
#   1 (restart 0) KSP residual norm 6.003059e-03
#   2 (restart 0) KSP residual norm 1.079792e-03
#   3 (restart 0) KSP residual norm 1.846466e-04
#   4 (restart 0) KSP residual norm 3.695188e-05
#   5 (restart 0) KSP residual norm 8.498904e-06
#   6 (restart 0) KSP residual norm 1.957044e-06
#   7 (restart 0) KSP residual norm 4.384578e-07
#   8 (restart 0) KSP residual norm 8.840216e-08
#   9 (restart 0) KSP residual norm 1.771356e-08
#  10 (restart 0) KSP residual norm 3.657320e-09
#  11 (restart 0) KSP residual norm 8.358588e-10
#  12 (restart 0) KSP residual norm 1.916774e-10
# FGMRES solver converged in 12 iterations (avg. reduction factor: 1.970e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 2.228425e-01
#   1 (restart 0) KSP residual norm 1.765907e-02
#   2 (restart 0) KSP residual norm 2.499044e-03
#   3 (restart 0) KSP residual norm 4.556209e-04
#   4 (restart 0) KSP residual norm 9.905711e-05
#   5 (restart 0) KSP residual norm 2.227072e-05
#   6 (restart 0) KSP residual norm 4.503221e-06
#   7 (restart 0) KSP residual norm 8.831833e-07
#   8 (restart 0) KSP residual norm 1.738206e-07
#   9 (restart 0) KSP residual norm 3.591952e-08
#  10 (restart 0) KSP residual norm 7.611438e-09
#  11 (restart 0) KSP residual norm 1.598835e-09
# FGMRES solver converged in 11 iterations (avg. reduction factor: 1.818e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 4.357800e-02
#   1 (restart 0) KSP residual norm 5.343394e-03
#   2 (restart 0) KSP residual norm 8.954871e-04
#   3 (restart 0) KSP residual norm 1.543829e-04
#   4 (restart 0) KSP residual norm 3.306094e-05
#   5 (restart 0) KSP residual norm 7.775603e-06
#   6 (restart 0) KSP residual norm 1.795277e-06
#   7 (restart 0) KSP residual norm 3.823755e-07
#   8 (restart 0) KSP residual norm 7.739157e-08
#   9 (restart 0) KSP residual norm 1.543299e-08
#  10 (restart 0) KSP residual norm 3.123104e-09
#  11 (restart 0) KSP residual norm 7.145206e-10
#  12 (restart 0) KSP residual norm 1.734406e-10
# FGMRES solver converged in 12 iterations (avg. reduction factor: 1.995e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 3.722286e-01
#   1 (restart 0) KSP residual norm 2.991496e-02
#   2 (restart 0) KSP residual norm 4.149921e-03
#   3 (restart 0) KSP residual norm 7.414187e-04
#   4 (restart 0) KSP residual norm 1.570003e-04
#   5 (restart 0) KSP residual norm 3.409148e-05
#   6 (restart 0) KSP residual norm 7.010598e-06
#   7 (restart 0) KSP residual norm 1.345348e-06
#   8 (restart 0) KSP residual norm 2.424739e-07
#   9 (restart 0) KSP residual norm 4.896267e-08
#  10 (restart 0) KSP residual norm 9.791815e-09
#  11 (restart 0) KSP residual norm 2.046679e-09
# FGMRES solver converged in 11 iterations (avg. reduction factor: 1.775e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 2.475508e-02
#   1 (restart 0) KSP residual norm 5.584585e-03
#   2 (restart 0) KSP residual norm 9.452483e-04
#   3 (restart 0) KSP residual norm 1.589644e-04
#   4 (restart 0) KSP residual norm 3.098875e-05
#   5 (restart 0) KSP residual norm 6.594097e-06
#   6 (restart 0) KSP residual norm 1.429919e-06
#   7 (restart 0) KSP residual norm 3.077820e-07
#   8 (restart 0) KSP residual norm 7.109160e-08
#   9 (restart 0) KSP residual norm 1.734184e-08
#  10 (restart 0) KSP residual norm 4.167113e-09
#  11 (restart 0) KSP residual norm 9.548124e-10
#  12 (restart 0) KSP residual norm 2.014107e-10
# FGMRES solver converged in 12 iterations (avg. reduction factor: 2.118e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 3.382158e-01
#   1 (restart 0) KSP residual norm 2.979124e-02
#   2 (restart 0) KSP residual norm 3.826210e-03
#   3 (restart 0) KSP residual norm 7.209102e-04
#   4 (restart 0) KSP residual norm 1.532372e-04
#   5 (restart 0) KSP residual norm 3.550060e-05
#   6 (restart 0) KSP residual norm 6.983270e-06
#   7 (restart 0) KSP residual norm 1.246974e-06
#   8 (restart 0) KSP residual norm 2.028923e-07
#   9 (restart 0) KSP residual norm 4.026732e-08
#  10 (restart 0) KSP residual norm 9.336144e-09
#  11 (restart 0) KSP residual norm 2.071759e-09
# FGMRES solver converged in 11 iterations (avg. reduction factor: 1.792e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 4.426387e-02
#   1 (restart 0) KSP residual norm 5.599548e-03
#   2 (restart 0) KSP residual norm 9.527858e-04
#   3 (restart 0) KSP residual norm 1.761413e-04
#   4 (restart 0) KSP residual norm 3.674297e-05
#   5 (restart 0) KSP residual norm 8.436533e-06
#   6 (restart 0) KSP residual norm 1.907362e-06
#   7 (restart 0) KSP residual norm 4.003676e-07
#   8 (restart 0) KSP residual norm 8.408103e-08
#   9 (restart 0) KSP residual norm 1.877519e-08
#  10 (restart 0) KSP residual norm 4.568883e-09
#  11 (restart 0) KSP residual norm 1.097265e-09
#  12 (restart 0) KSP residual norm 2.392111e-10
# FGMRES solver converged in 12 iterations (avg. reduction factor: 2.047e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 3.947754e-01
#   1 (restart 0) KSP residual norm 4.200933e-02
#   2 (restart 0) KSP residual norm 4.816055e-03
#   3 (restart 0) KSP residual norm 8.598917e-04
#   4 (restart 0) KSP residual norm 1.800951e-04
#   5 (restart 0) KSP residual norm 4.010605e-05
#   6 (restart 0) KSP residual norm 7.503973e-06
#   7 (restart 0) KSP residual norm 1.391162e-06
#   8 (restart 0) KSP residual norm 2.651901e-07
#   9 (restart 0) KSP residual norm 5.508330e-08
#  10 (restart 0) KSP residual norm 1.230851e-08
#  11 (restart 0) KSP residual norm 2.498356e-09
# FGMRES solver converged in 11 iterations (avg. reduction factor: 1.797e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 1.468286e-01
#   1 (restart 0) KSP residual norm 1.620489e-02
#   2 (restart 0) KSP residual norm 2.005776e-03
#   3 (restart 0) KSP residual norm 3.589629e-04
#   4 (restart 0) KSP residual norm 7.648180e-05
#   5 (restart 0) KSP residual norm 1.658598e-05
#   6 (restart 0) KSP residual norm 3.190887e-06
#   7 (restart 0) KSP residual norm 6.000027e-07
#   8 (restart 0) KSP residual norm 1.171025e-07
#   9 (restart 0) KSP residual norm 2.530805e-08
#  10 (restart 0) KSP residual norm 5.962276e-09
#  11 (restart 0) KSP residual norm 1.384807e-09
# FGMRES solver converged in 11 iterations (avg. reduction factor: 1.864e-01)
#   Residual norms for FGMRES solve
#   0 (restart 0) KSP residual norm 2.593392e-01
#   1 (restart 0) KSP residual norm 2.769260e-02
#   2 (restart 0) KSP residual norm 3.045481e-03
#   3 (restart 0) KSP residual norm 4.971448e-04
#   4 (restart 0) KSP residual norm 9.166704e-05
#   5 (restart 0) KSP residual norm 2.124517e-05
#   6 (restart 0) KSP residual norm 4.552097e-06
#   7 (restart 0) KSP residual norm 8.966192e-07
#   8 (restart 0) KSP residual norm 1.715018e-07
#   9 (restart 0) KSP residual norm 3.234365e-08
#  10 (restart 0) KSP residual norm 7.464320e-09
#  11 (restart 0) KSP residual norm 1.831333e-09
# FGMRES solver converged in 11 iterations (avg. reduction factor: 1.815e-01)
#   1 EPS nconv=1 first unconverged value (error) 0.000186999+1.25499e-12i (4.46192915e-06)
#
#  Linear eigensolve converged (1 eigenpair) due to CONVERGED_TOL; iterations 1
#  Total number of linear systems solved: 16
#  Total number of linear solver iterations: 185
#  Found 1 converged eigenvalue (first = 4.794e-02+9.707e-08i)
#
# Computing solution error estimates and performing postprocessing
#
#      m,        Re{f} (GHz),        Im{f} (GHz),                  Q,      Error (Bkwd.),       Error (Abs.)
#      1,      +1.044646e+01,      +1.057711e-05,      +4.938240e+05,      +6.836865e-15,      +6.190692e-11
#  Wrote mode 1 to disk (Paraview)
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 2.723e-01, global unknowns = 96622
#  Max. iterations = 0, tol. = 1.000e-02
#
# Estimated peak per-rank memory usage is: Min. 126.7M, Max. 140.0M, Avg. 132.8M, Total 1.0G
# Estimated peak per-node memory usage is: Min. 1.0G, Max. 1.0G, Avg. 1.0G, Total 1.0G
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.037       0.231       0.206
#   Mesh Preprocessing             0.078       0.272       0.102
# Operator Construction            0.638       0.638       0.638
# Linear Solve                     1.646       1.759       1.667
#   Setup                          1.271       1.271       1.271
#   Preconditioner                20.881      20.993      20.971
#   Coarse Solve                   1.731       1.734       1.733
# Eigenvalue Solve                 0.131       0.134       0.133
# Div.-Free Projection             2.624       2.626       2.625
# Estimation                       0.016       0.017       0.017
#   Construction                   0.663       0.664       0.663
#   Solve                          0.429       0.430       0.429
# Postprocessing                   0.070       0.071       0.070
#   Paraview                       0.711       0.712       0.712
# Disk IO                          0.071       0.073       0.072
# --------------------------------------------------------------
# Total                           31.363      31.386      31.376
#
# Peak Memory                   Per-Node       Total   Total HWM
# ==============================================================
# Initialization                   37.4M       37.4M       37.4M
#   Mesh Preprocessing             32.8M       32.8M       70.1M
# Operator Construction           206.0M      206.0M      276.1M
# Linear Solve                      1.8M        1.8M      277.9M
#   Setup                         138.7M      138.7M      416.5M
#   Preconditioner                  6.5M        6.5M      423.0M
#   Coarse Solve                  275.1M      275.1M      698.2M
# Eigenvalue Solve                  2.6M        2.6M      700.8M
# Div.-Free Projection             25.9M       25.9M      726.7M
# Estimation                       15.2M       15.2M      741.9M
#   Construction                   64.8M       64.8M      806.7M
#   Solve                          10.7M       10.7M      817.3M
# Postprocessing                  364.0K      364.0K      817.7M
#   Paraview                        6.7M        6.7M      824.3M
# Disk IO                           7.0M        7.0M      831.3M
# --------------------------------------------------------------
# Total                           889.6M      889.6M      889.6M
#
# Error in plotting: 'Data array (E_real) not present in this dataset.'
# array([[1.00000000e+00, 1.04464646e+01, 1.05771139e-05, 4.93823961e+05,
#         6.83686458e-15, 6.19069191e-11]])

# %%
# Retrieve the eigenfrequency data
data = eigen_sim.retrieve_data()
print(data)

# Or for EPR (participation ratio) data if you set up EPR interfaces:
epr_data = eigen_sim.retrieve_EPR_data()
print(epr_data)
# Out:
# Error in plotting: 'Data array (E_real) not present in this dataset.'
# [[1.00000000e+00 1.04464646e+01 1.05771139e-05 4.93823961e+05
#   6.83686458e-15 6.19069191e-11]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 6
#       2 data = eigen_sim.retrieve_data()
#       3 print(data)
#       4
#       5 # Or for EPR (participation ratio) data if you set up EPR interfaces:
# ----> 6 epr_data = eigen_sim.retrieve_EPR_data()
#       7 print(epr_data)
#
# AttributeError: 'PALACE_Eigenmode_Simulation' object has no attribute 'retrieve_EPR_data'

# %%
eigen_sim.calculate_hamiltonian_parameters_EPR()
# Out:
# Simulation Mode Frequencies:
#         Freq (GHz)
# mode_1   10.446465
# ______________________________
#
# Renormalised Frequencies:
#  ***Freqs from simulation are adjusted for Lamb shift
#         Freq (GHz)
# mode_1    10.09314
# ______________________________
#
# Participation Ratios:
#             jj_1
# mode_1  0.992281
# ______________________________
#
# Chi Matrix (MHz):
#  ***Diag is Anharmonicity, Off-Diag is Cross-Kerr
#             mode_1
# mode_1  353.324478
# ______________________________
#
# Lamb Shifts:
#         Lamb Shift (MHz)
# mode_1        353.324478
# ______________________________
#
# Detuning (GHz):
#         mode_1
# mode_1     0.0
# ______________________________
# {'f_modes_GHz':         Freq (GHz)
#  mode_1   10.446465,
#  'f_norms_GHz':         Freq (GHz)
#  mode_1    10.09314,
#  'EPR':             jj_1
#  mode_1  0.992281,
#  'Chi':             mode_1
#  mode_1  353.324478,
#  'Lamb':         Lamb Shift (MHz)
#  mode_1        353.324478,
#  'Detuning':         mode_1
#  mode_1     0.0}
